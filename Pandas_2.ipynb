# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
import numpy as np

# %%
# it gives me all indexes where we have null values for age column.
df_age_null = np.where(df['Age'].isnull() == True)

# %%
df.iloc[df_age_null]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.iloc[[2,434,67,89,9]]
# Out:
#      PassengerId  Survived  Pclass                                 Name  \
# 2              3         1       3               Heikkinen, Miss. Laina
# 434          435         0       1            Silvey, Mr. William Baird
# 67            68         0       3             Crease, Mr. Ernest James
# 89            90         0       3               Celotti, Mr. Francesco
# 9             10         1       2  Nasser, Mrs. Nicholas (Adele Achem)
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 434    male  50.0      1      0             13507  55.9000   E44        S
# 67     male  19.0      0      0         S.P. 3464   8.1583   NaN        S
# 89     male  24.0      0      0            343275   8.0500   NaN        S
# 9    female  14.0      1      0            237736  30.0708   NaN        C

# %% [markdown]
# ### Name of persons with maximum fare?

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
df['Name'][df['Fare'] == max(df['Fare'])]
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df.iloc[[258,679,737]]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
np.where(df['Fare'] == max(df['Fare']))
# Out:
# (array([258, 679, 737], dtype=int64),)

# %%
df.iloc[np.where(df['Fare'] == max(df['Fare']))]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %% [markdown]
# ### Name of person(s) with minimum age?

# %% [markdown]
# #### Method - I

# %%
df['Name'][df['Age'] == min(df['Age'])]
# Out:
# 803    Thomas, Master. Assad Alexander
# Name: Name, dtype: object

# %% [markdown]
# #### Method - II

# %%
df[df['Age'] == df['Age'].min()]['Name']
# Out:
# 803    Thomas, Master. Assad Alexander
# Name: Name, dtype: object

# %% [markdown]
# #### Method - III

# %%
df.iloc[np.where(df['Age'] == min(df['Age']))]['Name']
# Out:
# 803    Thomas, Master. Assad Alexander
# Name: Name, dtype: object

# %%
# Persons with age 24.
df[df['Age'] == 24]['Name']
# Out:
# 89                                Celotti, Mr. Francesco
# 118                             Baxter, Mr. Quigg Edmond
# 127                            Madsen, Mr. Fridtjof Arne
# 139                                   Giglio, Mr. Victor
# 142    Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...
# 199               Yrois, Miss. Henriette ("Mrs Harbeck")
# 210                                       Ali, Mr. Ahmed
# 234                    Leyson, Mr. Robert William Norman
# 247                      Hamalainen, Mrs. William (Anna)
# 293                                  Haas, Miss. Aloisia
# 294                                     Mineff, Mr. Ivan
# 310                       Hays, Miss. Margaret Bechstein
# 316                  Kantor, Mrs. Sinai (Miriam Sternin)
# 341                       Fortune, Miss. Alice Elizabeth
# 345                        Brown, Miss. Amelia "Mildred"
# 369                        Aubart, Mme. Leontine Pauline
# ...

# %%
#Age of person whose cabin as NaN.
df['Age'][df['Cabin'].isnull()]
# Out:
# 0      22.0
# 2      26.0
# 4      35.0
# 5       NaN
# 7       2.0
#        ...
# 884    25.0
# 885    39.0
# 886    27.0
# 888     NaN
# 890    32.0
# Name: Age, Length: 687, dtype: float64

# %% [markdown]
# ### Find how many passengers have survived who are male?

# %%
type(df.groupby('Sex'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
df['Name'][(df['Sex'] == 'male') & (df['Survived'] == 1)]
# Out:
# 17        Williams, Mr. Charles Eugene
# 21               Beesley, Mr. Lawrence
# 23        Sloper, Mr. William Thompson
# 36                    Mamee, Mr. Hanna
# 55                   Woolner, Mr. Hugh
#                     ...
# 838                    Chip, Mr. Chang
# 839               Marechal, Mr. Pierre
# 857             Daly, Mr. Peter Denis
# 869    Johnson, Master. Harold Theodor
# 889              Behr, Mr. Karl Howell
# Name: Name, Length: 109, dtype: object

# %%
df[0:30]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %% [markdown]
# #### Series and DataFrame

# %%
s = ['4.5','sudh',65]

# %%
pd.Series(s)
# Out:
# 0     4.5
# 1    sudh
# 2      65
# dtype: object

# %%
d = {'ravi' : ['wagonr', 'yamaha','China'], 'sita' : ['swift','Aprilia','Italy'],'kishore' : ['mercedes','suzuki','Japan']}
index = ['Car','Bike','Place']
pd.DataFrame(d,index)
# Out:
#          ravi     sita   kishore
# Car    wagonr    swift  mercedes
# Bike   yamaha  Aprilia    suzuki
# Place   China    Italy     Japan

# %%
pd.Series(d)
# Out:
# ravi         [wagonr, yamaha, China]
# sita         [swift, Aprilia, Italy]
# kishore    [mercedes, suzuki, Japan]
# dtype: object

# %%
arr = np.random.randn(4,3)

# %%
pd.DataFrame(arr)
# Out:
#           0         1         2
# 0  0.620806  0.208353  1.399658
# 1 -0.409711 -0.638826 -1.306248
# 2  0.197679  0.751866  0.614535
# 3  1.391637 -1.210243 -0.663372

# %%
sar = np.array([3,5,6,7,8,9])
pd.Series(sar, index=['dara','sid','suf','nie','kus','fke'])
# Out:
# dara    3
# sid     5
# suf     6
# nie     7
# kus     8
# fke     9
# dtype: int32

# %%
ser1 = pd.Series(sar , index=[44,33,32,55,77,88])

# %%
# iloc takes only default integer indexes not named one which I have provided in this case even though they are integers.
ser1.iloc[44]      # gives error

# %%
ser1.loc[44]
# Out:
# 3

# %%
pd.DataFrame(np.random.randint(2,6,(3,5)))
# Out:
#    0  1  2  3  4
# 0  5  5  3  3  5
# 1  5  3  4  4  5
# 2  4  5  2  2  2

# %%
rd = pd.DataFrame(np.random.randint(2,6,(3,5)), index=['a','c','e'], columns=['z','x','v','t','r'])

# %%
rd
# Out:
#    z  x  v  t  r
# a  2  3  3  5  3
# c  4  5  2  5  5
# e  4  2  2  3  2

# %%
rd.loc["c":"e","x":"t"]
# Out:
#    x  v  t
# c  5  2  5
# e  2  2  3

# %%
rd.loc[('c','e'),('x','v','t')]
# Out:
#    x  v  t
# c  5  2  5
# e  2  2  3

# %%
rd.iloc[1:3,1:4]
# Out:
#    x  v  t
# c  5  2  5
# e  2  2  3

# %% [markdown]
# new column which holds the summation of column v and r

# %%
rd
# Out:
#    z  x  v  t  r
# a  2  3  3  5  3
# c  4  5  2  5  5
# e  4  2  2  3  2

# %%
rd['summ'] = rd['v'] + rd.r
rd
# Out:
#    z  x  v  t  r  summ
# a  2  3  3  5  3     6
# c  4  5  2  5  5     7
# e  4  2  2  3  2     4

# %%
# Permanently dropping column x
rd.drop('x', axis=1, inplace=True)

# %%
rd
# Out:
#    z  v  t  r  summ
# a  2  3  5  3     6
# c  4  2  5  5     7
# e  4  2  3  2     4

# %%
np.random.seed(23)
rn = pd.DataFrame(np.random.randn(4,5), index=['a','c','e','g'], columns=['z','x','v','t','r'])

# %%
rn
# Out:
#           z         x         v         t         r
# a  0.666988  0.025813 -0.777619  0.948634  0.701672
# c -1.051082 -0.367548 -1.137460 -1.322148  1.772258
# e -0.347459  0.670140  0.322272  0.060343 -1.043450
# g -1.009942  0.441736  1.128877 -1.838068 -0.938769

# %% [markdown]
# Extract all negative values from the data frame.

# %%
t = rn['z'][rn['z'] < 0]
t.values
# Out:
# array([-1.05108156, -0.34745899, -1.00994188])

# %%
rn.values[rn.values < 0]
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
rn.values[rn.iloc[0:5] < 0]
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
rn.index[rn['x'].iloc[0:5] < 0]
# Out:
# Index(['c'], dtype='object')

# %% [markdown]
# #### Get the row and column of all negative values in dataframe.

# %%
for i in rn.index:
    for j in rn.columns:
        if rn.loc[i,j] < 0:
            print(f'Row: {i}, Column: {j}, Value: {rn.loc[i,j]}')
# Out:
# Row: a, Column: v, Value: -0.7776194131918178
# Row: c, Column: z, Value: -1.0510815639071178
# Row: c, Column: x, Value: -0.3675481161171661
# Row: c, Column: v, Value: -1.1374596907250272
# Row: c, Column: t, Value: -1.3221475225908594
# Row: e, Column: z, Value: -0.34745899102186334
# Row: e, Column: r, Value: -1.0434500017467254
# Row: g, Column: z, Value: -1.0099418765878465
# Row: g, Column: t, Value: -1.8380677677579502
# Row: g, Column: r, Value: -0.9387686311201282

# %%
rn['v']['a']
# Out:
# -0.7776194131918178

# %%
import pandas as pd
import numpy as np

# %%
d = {'key1':[1,2,566,88,np.nan], "key2":["ram", 3,6,"rahim",9], 'key3': [5, np.nan, np.nan, 34, np.nan]}
df1 = pd.DataFrame(d)

# %%
df1
# Out:
#     key1   key2  key3
# 0    1.0    ram   5.0
# 1    2.0      3   NaN
# 2  566.0      6   NaN
# 3   88.0  rahim  34.0
# 4    NaN      9   NaN

# %%
# Drop all the rows having NaN or null values
df1.dropna()   # by default axis = 0 i.e. rows
# Out:
#    key1   key2  key3
# 0   1.0    ram   5.0
# 3  88.0  rahim  34.0

# %%
df1.dropna(axis=1)
# Out:
#     key2
# 0    ram
# 1      3
# 2      6
# 3  rahim
# 4      9

# %%
#thresh = Checks for atleast the threshold number of non-NA values.
df1.dropna(thresh=1)
# it checks every row & even 1 non-NA value is present, then it won't drop it.
# Out:
#     key1   key2  key3
# 0    1.0    ram   5.0
# 1    2.0      3   NaN
# 2  566.0      6   NaN
# 3   88.0  rahim  34.0
# 4    NaN      9   NaN

# %%
df1.dropna(thresh=2)
# Out:
#     key1   key2  key3
# 0    1.0    ram   5.0
# 1    2.0      3   NaN
# 2  566.0      6   NaN
# 3   88.0  rahim  34.0

# %%
df1.dropna(thresh=3)
# Out:
#    key1   key2  key3
# 0   1.0    ram   5.0
# 3  88.0  rahim  34.0

# %%
df1.dropna(thresh=3, axis=1)
# Out:
#     key1   key2
# 0    1.0    ram
# 1    2.0      3
# 2  566.0      6
# 3   88.0  rahim
# 4    NaN      9

# %%
df1.fillna('name')
# Out:
#     key1   key2  key3
# 0    1.0    ram   5.0
# 1    2.0      3  name
# 2  566.0      6  name
# 3   88.0  rahim  34.0
# 4   name      9  name

# %%
# Fill all na values with mean of key1 column.
df1.fillna(value = df1['key1'].mean())
# Out:
#      key1   key2    key3
# 0    1.00    ram    5.00
# 1    2.00      3  164.25
# 2  566.00      6  164.25
# 3   88.00  rahim   34.00
# 4  164.25      9  164.25

# %%
df1
# Out:
#     key1   key2  key3
# 0    1.0    ram   5.0
# 1    2.0      3   NaN
# 2  566.0      6   NaN
# 3   88.0  rahim  34.0
# 4    NaN      9   NaN

# %%
# Replace Nan in each column with mean of that column.
mean_k1 = df1['key1'].mean()
df1['key1'] = df1['key1'].fillna(mean_k1)
mean_k3 = df1['key3'].mean()
df1['key3'] = df1['key3'].fillna(mean_k3)

# %%
df1
# Out:
#      key1   key2  key3
# 0    1.00    ram   5.0
# 1    2.00      3  19.5
# 2  566.00      6  19.5
# 3   88.00  rahim  34.0
# 4  164.25      9  19.5

# %%
df1
# Out:
#      key1   key2  key3
# 0    1.00    ram   5.0
# 1    2.00      3  19.5
# 2  566.00      6  19.5
# 3   88.00  rahim  34.0
# 4  164.25      9  19.5

# %%
d = {'key1':[1,2,566,88,np.nan], "key2":[8,'ram',6,5,np.nan], 'key3': [5, np.nan, np.nan, 34, np.nan]}
df2 = pd.DataFrame(d)

# %%
df2
# Out:
#     key1 key2  key3
# 0    1.0    8   5.0
# 1    2.0  ram   NaN
# 2  566.0    6   NaN
# 3   88.0    5  34.0
# 4    NaN  NaN   NaN

# %%
df2.apply(lambda x: x.fillna(x.mode()),axis=1)
# Out:
# C:\Anaconda\lib\site-packages\pandas\core\algorithms.py:944: UserWarning: Unable to sort modes: '<' not supported between instances of 'float' and 'str'
#   warn(f"Unable to sort modes: {err}")
#     key1 key2  key3
# 0    1.0  8.0   5.0
# 1    2.0  ram   NaN
# 2  566.0  6.0   NaN
# 3   88.0  5.0  34.0
# 4    NaN  9.0   NaN

# %%
column_means = df2.mean()
df2.fillna(column_means)
# Out:
#      key1 key2  key3
# 0    1.00    8   5.0
# 1    2.00  ram  19.5
# 2  566.00    6  19.5
# 3   88.00    5  34.0
# 4  164.25  NaN  19.5

# %%
d1 = {'name':['sudh', 'ravi', 'jatin','ravi', 'sagar'], 
      'mail_id':['sudh@gmail.com', 'ravi@gmail.com', 'jatin@gmail.com','ravi@gmail.com', 'sagar@gmail.com'],
     'salary':[200, 400, 600, 300, 700]}

# %%
df = pd.DataFrame(d1)

# %%
# Mean salary of each person grouped by name
df.groupby('name').mean()
# Out:
#        salary
# name
# jatin     600
# ravi      350
# sagar     700
# sudh      200

# %%
# Total salary of each person gruped by email_id
df.groupby('mail_id').sum()
# Out:
#                  salary
# mail_id
# jatin@gmail.com     600
# ravi@gmail.com      700
# sagar@gmail.com     700
# sudh@gmail.com      200

# %%
df.groupby('mail_id').describe()
# Out:
#                 salary
#                  count   mean        std    min    25%    50%    75%    max
# mail_id
# jatin@gmail.com    1.0  600.0        NaN  600.0  600.0  600.0  600.0  600.0
# ravi@gmail.com     2.0  350.0  70.710678  300.0  325.0  350.0  375.0  400.0
# sagar@gmail.com    1.0  700.0        NaN  700.0  700.0  700.0  700.0  700.0
# sudh@gmail.com     1.0  200.0        NaN  200.0  200.0  200.0  200.0  200.0

# %%
#I want to extract ravi's data from above describe table. We can use either loc or iloc.
df.groupby('mail_id').describe().loc['ravi@gmail.com']
#df.groupby('mail_id').describe().iloc[1]
# Out:
# salary  count      2.000000
#         mean     350.000000
#         std       70.710678
#         min      300.000000
#         25%      325.000000
#         50%      350.000000
#         75%      375.000000
#         max      400.000000
# Name: ravi@gmail.com, dtype: float64

# %%
# I have to extract 350 corr. to mean from above series. We can use indexing to extract it.
#df.groupby('mail_id').describe().loc['ravi@gmail.com'][1]
df.groupby('mail_id').describe().loc['ravi@gmail.com']['salary']['mean']
# Out:
# 350.0

# %%
# I have to interchange rows and columns. We can use alias T which stands for transpose.
df.groupby('mail_id').describe().T
# Out:
# mail_id       jatin@gmail.com  ravi@gmail.com  sagar@gmail.com  sudh@gmail.com
# salary count              1.0        2.000000              1.0             1.0
#        mean             600.0      350.000000            700.0           200.0
#        std                NaN       70.710678              NaN             NaN
#        min              600.0      300.000000            700.0           200.0
#        25%              600.0      325.000000            700.0           200.0
#        50%              600.0      350.000000            700.0           200.0
#        75%              600.0      375.000000            700.0           200.0
#        max              600.0      400.000000            700.0           200.0

# %%
arr1 = np.random.randn(3,4)
arr2 = np.random.randn(3,4)
arr3 = np.random.randn(3,4)

# %%
df1 = pd.DataFrame(arr1, columns=['A','B','C','D'], index=[0,1,2])
df2 = pd.DataFrame(arr2, columns=['A','B','C','D'], index=[0,1,2])
df3 = pd.DataFrame(arr3, columns=['A','B','C','D'], index=[0,1,2])

# %%
#We have to merge the above 3 dataframes one below the other (vertical concatenation or row-wise concatenation where axis=0).
df4 = pd.concat([df1,df2,df3])

# %%
df5 = pd.concat([df1,df2,df3], axis=1)

# %%
# As by default the indexes are in order from 0 onwards even though our table has repeated indexes & iloc gets data from defult indices.
df4.iloc[0]
# Out:
# A    0.864902
# B    1.194400
# C   -0.748470
# D   -1.332038
# Name: 0, dtype: float64

# %%
#Since loc gives values of named indices, it gives all rows having 0 index.
df4.loc[0]
# Out:
#           A         B         C         D
# 0  0.864902  1.194400 -0.748470 -1.332038
# 0  1.720337  1.328396  1.635770 -1.734861
# 0 -0.186017  0.408594 -0.283586  0.167131

# %%
df5
# Out:
#           A         B         C         D         A         B        C  \
# 0  0.864902  1.194400 -0.748470 -1.332038  1.720337  1.328396  1.63577
# 1  0.119475  0.913354 -1.122496  0.774328 -0.308339 -0.947972  1.61951
# 2 -0.899010 -0.126938  0.171494 -0.136797  0.796136 -0.188644 -1.34918
#
#           D         A         B         C         D
# 0 -1.734861 -0.186017  0.408594 -0.283586  0.167131
# 1  0.416794  2.205815 -0.038774  0.972690 -0.402283
# 2 -1.222662 -0.593732 -0.320160 -1.194090  0.649444

# %%
df5.loc[:,'A']   # all rows and column='A'
# Out:
#           A         A         A
# 0  0.864902  1.720337 -0.186017
# 1  0.119475 -0.308339  2.205815
# 2 -0.899010  0.796136 -0.593732

# %%
#But we want only the second A column.
df5.iloc[:,4]
# Out:
# 0    1.720337
# 1   -0.308339
# 2    0.796136
# Name: A, dtype: float64

# %%
df11 = pd.DataFrame(arr1, columns=['A','B','C','D'], index=[0,1,2])
df22 = pd.DataFrame(arr2, columns=['A','B','C','D'], index=[3,4,5])
df33 = pd.DataFrame(arr3, columns=['A','B','C','D'], index=[6,7,8])

# %%
pd.concat([df11,df22,df33], axis=1)
# Out:
#           A         B         C         D         A         B        C  \
# 0  0.864902  1.194400 -0.748470 -1.332038       NaN       NaN      NaN
# 1  0.119475  0.913354 -1.122496  0.774328       NaN       NaN      NaN
# 2 -0.899010 -0.126938  0.171494 -0.136797       NaN       NaN      NaN
# 3       NaN       NaN       NaN       NaN  1.720337  1.328396  1.63577
# 4       NaN       NaN       NaN       NaN -0.308339 -0.947972  1.61951
# 5       NaN       NaN       NaN       NaN  0.796136 -0.188644 -1.34918
# 6       NaN       NaN       NaN       NaN       NaN       NaN      NaN
# 7       NaN       NaN       NaN       NaN       NaN       NaN      NaN
# 8       NaN       NaN       NaN       NaN       NaN       NaN      NaN
#
#           D         A         B         C         D
# 0       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN
# ...

# %%
#Fill all NaN with 0.
pd.concat([df11,df22,df33], axis=1).fillna(0)
# Out:
#           A         B         C         D         A         B        C  \
# 0  0.864902  1.194400 -0.748470 -1.332038  0.000000  0.000000  0.00000
# 1  0.119475  0.913354 -1.122496  0.774328  0.000000  0.000000  0.00000
# 2 -0.899010 -0.126938  0.171494 -0.136797  0.000000  0.000000  0.00000
# 3  0.000000  0.000000  0.000000  0.000000  1.720337  1.328396  1.63577
# 4  0.000000  0.000000  0.000000  0.000000 -0.308339 -0.947972  1.61951
# 5  0.000000  0.000000  0.000000  0.000000  0.796136 -0.188644 -1.34918
# 6  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 7  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
# 8  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000
#
#           D         A         B         C         D
# 0  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000
# ...

# %%
np.random.seed(23)
arr1 = np.random.randn(3,4)
np.random.seed(23)
arr2 = np.random.randn(3,4)
df11 = pd.DataFrame(arr1, columns=['A','B','C','D'], index=[0,1,2])
df22 = pd.DataFrame(arr2, columns=['A','B','C','D'], index=[3,4,5])

# %%
df11
# Out:
#           A         B         C         D
# 0  0.666988  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140

# %%
df22
# Out:
#           A         B         C         D
# 3  0.666988  0.025813 -0.777619  0.948634
# 4  0.701672 -1.051082 -0.367548 -1.137460
# 5 -1.322148  1.772258 -0.347459  0.670140

# %%
# Merge operation based on same column A
pd.merge(df11,df22, on='A')
# Out:
#           A       B_x       C_x       D_x       B_y       C_y       D_y
# 0  0.666988  0.025813 -0.777619  0.948634  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140  1.772258 -0.347459  0.670140

# %%
df1 = pd.DataFrame({'key': ['K0', 'K8', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
df2 = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
df1
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K8  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
df2
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(df1,df2, on='key')  # this is by defult inner merge with only intersecting data
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K2  A2  B2  C2  D2
# 2  K3  A3  B3  C3  D3

# %%
# Left merge will consider everything from my left dataframe and whatever data is not present in right table will be NaN.
pd.merge(df1,df2, on='key', how='left')
# Out:
#   key   A   B    C    D
# 0  K0  A0  B0   C0   D0
# 1  K8  A1  B1  NaN  NaN
# 2  K2  A2  B2   C2   D2
# 3  K3  A3  B3   C3   D3

# %%
pd.merge(df1,df2, on='key', how="right")
# Out:
#   key    A    B   C   D
# 0  K0   A0   B0  C0  D0
# 1  K1  NaN  NaN  C1  D1
# 2  K2   A2   B2  C2  D2
# 3  K3   A3   B3  C3  D3

# %%
# Outer join will consider both left and right data frames completely & wherever value not present will be filled with NaN.
pd.merge(df1,df2, on='key', how="outer")

# %%
df1 = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})
    
df2 = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                               'key2': ['K0', 'K0', 'K0', 'K0'],
                                  'C': ['C0', 'C1', 'C2', 'C3'],
                                  'D': ['D0', 'D1', 'D2', 'D3']})

# %%
df1
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
df2
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
pd.merge(df1,df2,on=['key1','key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %% [markdown]
# ### JOIN OPERATIONS

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2']) 

df2 = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
df1
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
df2
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
# join operation performs join based on indexes while merge was based on columns.
df1.join(df2)    # similar to left join where df1 is left dataframe and df2 is right.
# by default it takes how='left' which we can change to right.
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
df1.join(df2, how='right')  # here df2 is my right dataframe.
# Out:
#       A    B   C   D
# K0   A0   B0  C0  D0
# K2   A2   B2  C2  D2
# K3  NaN  NaN  C3  D3

# %% [markdown]
# ### APPLY and GROUPBY operations

# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(20)
df = pd.DataFrame(np.random.randn(10,4), index = pd.date_range('2022-06-28', periods=10), columns =['a','b','c','d'])

# %%
df
# Out:
#                    a         b         c         d
# 2022-06-28  0.883893  0.195865  0.357537 -2.343262
# 2022-06-29 -1.084833  0.559696  0.939469 -0.978481
# 2022-06-30  0.503097  0.406414  0.323461 -0.493411
# 2022-07-01 -0.792017 -0.842368 -1.279503  0.245715
# 2022-07-02 -0.044195  1.567633  1.051109  0.406368
# 2022-07-03 -0.168646 -3.189703  1.120132  1.332778
# 2022-07-04 -0.243339 -0.130031 -0.109017  1.556186
# 2022-07-05  0.128778 -2.066949 -0.885493 -1.104579
# 2022-07-06  0.932866  2.059838 -0.934938 -1.612990
# 2022-07-07  0.527070 -1.551101  0.329613 -1.136527

# %%
df['new'] = df['c'] + df['d']

# %%
df
# Out:
#                    a         b         c         d       new
# 2022-06-28  0.883893  0.195865  0.357537 -2.343262 -1.985725
# 2022-06-29 -1.084833  0.559696  0.939469 -0.978481 -0.039012
# 2022-06-30  0.503097  0.406414  0.323461 -0.493411 -0.169950
# 2022-07-01 -0.792017 -0.842368 -1.279503  0.245715 -1.033787
# 2022-07-02 -0.044195  1.567633  1.051109  0.406368  1.457477
# 2022-07-03 -0.168646 -3.189703  1.120132  1.332778  2.452910
# 2022-07-04 -0.243339 -0.130031 -0.109017  1.556186  1.447169
# 2022-07-05  0.128778 -2.066949 -0.885493 -1.104579 -1.990073
# 2022-07-06  0.932866  2.059838 -0.934938 -1.612990 -2.547928
# 2022-07-07  0.527070 -1.551101  0.329613 -1.136527 -0.806913

# %%
df['square_col_d'] = df['d'].apply(lambda x: x*x)
df
# Out:
#                    a         b         c         d       new  square_col_d
# 2022-06-28  0.883893  0.195865  0.357537 -2.343262 -1.985725      5.490876
# 2022-06-29 -1.084833  0.559696  0.939469 -0.978481 -0.039012      0.957425
# 2022-06-30  0.503097  0.406414  0.323461 -0.493411 -0.169950      0.243454
# 2022-07-01 -0.792017 -0.842368 -1.279503  0.245715 -1.033787      0.060376
# 2022-07-02 -0.044195  1.567633  1.051109  0.406368  1.457477      0.165135
# 2022-07-03 -0.168646 -3.189703  1.120132  1.332778  2.452910      1.776298
# 2022-07-04 -0.243339 -0.130031 -0.109017  1.556186  1.447169      2.421716
# 2022-07-05  0.128778 -2.066949 -0.885493 -1.104579 -1.990073      1.220096
# 2022-07-06  0.932866  2.059838 -0.934938 -1.612990 -2.547928      2.601737
# 2022-07-07  0.527070 -1.551101  0.329613 -1.136527 -0.806913      1.291693

# %%
df['log_col_d'] = df['d'].apply(lambda x: np.log(x))
df
# Out:
#                    a         b         c         d       new  square_col_d  \
# 2022-06-28  0.883893  0.195865  0.357537 -2.343262 -1.985725      5.490876
# 2022-06-29 -1.084833  0.559696  0.939469 -0.978481 -0.039012      0.957425
# 2022-06-30  0.503097  0.406414  0.323461 -0.493411 -0.169950      0.243454
# 2022-07-01 -0.792017 -0.842368 -1.279503  0.245715 -1.033787      0.060376
# 2022-07-02 -0.044195  1.567633  1.051109  0.406368  1.457477      0.165135
# 2022-07-03 -0.168646 -3.189703  1.120132  1.332778  2.452910      1.776298
# 2022-07-04 -0.243339 -0.130031 -0.109017  1.556186  1.447169      2.421716
# 2022-07-05  0.128778 -2.066949 -0.885493 -1.104579 -1.990073      1.220096
# 2022-07-06  0.932866  2.059838 -0.934938 -1.612990 -2.547928      2.601737
# 2022-07-07  0.527070 -1.551101  0.329613 -1.136527 -0.806913      1.291693
#
#             log_col_d
# 2022-06-28        NaN
# 2022-06-29        NaN
# 2022-06-30        NaN
# 2022-07-01  -1.403582
# 2022-07-02  -0.900495
# ...

# %% [markdown]
# If there are negative data in column d, then keep it as it is and replace other data by their respective log values in new_col_d.

# %%
# Define function to keep negative data untouched and log of remaining.
def test(x):
    if (x<0):
        return x
    else:
        return np.log(x)

# %%
df['new_log_col_d'] = df['d'].apply(test)

# %%
df
# Out:
#                    a         b         c         d       new  square_col_d  \
# 2022-06-28  0.883893  0.195865  0.357537 -2.343262 -1.985725      5.490876
# 2022-06-29 -1.084833  0.559696  0.939469 -0.978481 -0.039012      0.957425
# 2022-06-30  0.503097  0.406414  0.323461 -0.493411 -0.169950      0.243454
# 2022-07-01 -0.792017 -0.842368 -1.279503  0.245715 -1.033787      0.060376
# 2022-07-02 -0.044195  1.567633  1.051109  0.406368  1.457477      0.165135
# 2022-07-03 -0.168646 -3.189703  1.120132  1.332778  2.452910      1.776298
# 2022-07-04 -0.243339 -0.130031 -0.109017  1.556186  1.447169      2.421716
# 2022-07-05  0.128778 -2.066949 -0.885493 -1.104579 -1.990073      1.220096
# 2022-07-06  0.932866  2.059838 -0.934938 -1.612990 -2.547928      2.601737
# 2022-07-07  0.527070 -1.551101  0.329613 -1.136527 -0.806913      1.291693
#
#             log_col_d  new_log_col_d
# 2022-06-28        NaN      -2.343262
# 2022-06-29        NaN      -0.978481
# ...

# %%
If dataset in col a is positive then 1 & if negative then 0, print in new column.

# %%
def test1(x):
    if x<0:
        return 1
    else:
        return 0

# %%
df['bin_col_a'] = df['a'].apply(test1)

# %%
df
# Out:
#                    a         b         c         d       new  square_col_d  \
# 2022-06-28  0.883893  0.195865  0.357537 -2.343262 -1.985725      5.490876
# 2022-06-29 -1.084833  0.559696  0.939469 -0.978481 -0.039012      0.957425
# 2022-06-30  0.503097  0.406414  0.323461 -0.493411 -0.169950      0.243454
# 2022-07-01 -0.792017 -0.842368 -1.279503  0.245715 -1.033787      0.060376
# 2022-07-02 -0.044195  1.567633  1.051109  0.406368  1.457477      0.165135
# 2022-07-03 -0.168646 -3.189703  1.120132  1.332778  2.452910      1.776298
# 2022-07-04 -0.243339 -0.130031 -0.109017  1.556186  1.447169      2.421716
# 2022-07-05  0.128778 -2.066949 -0.885493 -1.104579 -1.990073      1.220096
# 2022-07-06  0.932866  2.059838 -0.934938 -1.612990 -2.547928      2.601737
# 2022-07-07  0.527070 -1.551101  0.329613 -1.136527 -0.806913      1.291693
#
#             log_col_d  new_log_col_d  bin_col_a
# 2022-06-28        NaN      -2.343262          0
# ...

# %% [markdown]
# ##### Sort data in column b

# %%
df.sort_values(by = 'b') # by default ascending = True
# Out:
#                    a         b         c         d       new  square_col_d  \
# 2022-07-03 -0.168646 -3.189703  1.120132  1.332778  2.452910      1.776298
# 2022-07-05  0.128778 -2.066949 -0.885493 -1.104579 -1.990073      1.220096
# 2022-07-07  0.527070 -1.551101  0.329613 -1.136527 -0.806913      1.291693
# 2022-07-01 -0.792017 -0.842368 -1.279503  0.245715 -1.033787      0.060376
# 2022-07-04 -0.243339 -0.130031 -0.109017  1.556186  1.447169      2.421716
# 2022-06-28  0.883893  0.195865  0.357537 -2.343262 -1.985725      5.490876
# 2022-06-30  0.503097  0.406414  0.323461 -0.493411 -0.169950      0.243454
# 2022-06-29 -1.084833  0.559696  0.939469 -0.978481 -0.039012      0.957425
# 2022-07-02 -0.044195  1.567633  1.051109  0.406368  1.457477      0.165135
# 2022-07-06  0.932866  2.059838 -0.934938 -1.612990 -2.547928      2.601737
#
#             log_col_d  new_log_col_d  bin_col_a
# 2022-07-03   0.287266       0.287266          1
# ...

# %%
df['new_date'] = df.index
df
# Out:
#                    a         b         c         d       new  square_col_d  \
# 2022-06-28  0.883893  0.195865  0.357537 -2.343262 -1.985725      5.490876
# 2022-06-29 -1.084833  0.559696  0.939469 -0.978481 -0.039012      0.957425
# 2022-06-30  0.503097  0.406414  0.323461 -0.493411 -0.169950      0.243454
# 2022-07-01 -0.792017 -0.842368 -1.279503  0.245715 -1.033787      0.060376
# 2022-07-02 -0.044195  1.567633  1.051109  0.406368  1.457477      0.165135
# 2022-07-03 -0.168646 -3.189703  1.120132  1.332778  2.452910      1.776298
# 2022-07-04 -0.243339 -0.130031 -0.109017  1.556186  1.447169      2.421716
# 2022-07-05  0.128778 -2.066949 -0.885493 -1.104579 -1.990073      1.220096
# 2022-07-06  0.932866  2.059838 -0.934938 -1.612990 -2.547928      2.601737
# 2022-07-07  0.527070 -1.551101  0.329613 -1.136527 -0.806913      1.291693
#
#             log_col_d  new_log_col_d  bin_col_a   new_date
# 2022-06-28        NaN      -2.343262          0 2022-06-28
# ...

# %%
df.dtypes
# Out:
# a                       float64
# b                       float64
# c                       float64
# d                       float64
# new                     float64
# square_col_d            float64
# log_col_d               float64
# new_log_col_d           float64
# bin_col_a                 int64
# new_date         datetime64[ns]
# dtype: object

# %%
# I have to seperate year, month and date from the new_date column and create three different columns.
df['day'] = df.index.day
df['month'] = df.index.month
df['year'] = df.index.year
df
# Out:
#                    a         b         c         d       new  square_col_d  \
# 2022-06-28  0.883893  0.195865  0.357537 -2.343262 -1.985725      5.490876
# 2022-06-29 -1.084833  0.559696  0.939469 -0.978481 -0.039012      0.957425
# 2022-06-30  0.503097  0.406414  0.323461 -0.493411 -0.169950      0.243454
# 2022-07-01 -0.792017 -0.842368 -1.279503  0.245715 -1.033787      0.060376
# 2022-07-02 -0.044195  1.567633  1.051109  0.406368  1.457477      0.165135
# 2022-07-03 -0.168646 -3.189703  1.120132  1.332778  2.452910      1.776298
# 2022-07-04 -0.243339 -0.130031 -0.109017  1.556186  1.447169      2.421716
# 2022-07-05  0.128778 -2.066949 -0.885493 -1.104579 -1.990073      1.220096
# 2022-07-06  0.932866  2.059838 -0.934938 -1.612990 -2.547928      2.601737
# 2022-07-07  0.527070 -1.551101  0.329613 -1.136527 -0.806913      1.291693
#
#             log_col_d  new_log_col_d  bin_col_a   new_date  day  month  year
# ...

# %%
# I want a new column with name of week day.
df['week_Day'] = df.index.day_name()
df
# Out:
#                    a         b         c         d       new  square_col_d  \
# 2022-06-28  0.883893  0.195865  0.357537 -2.343262 -1.985725      5.490876
# 2022-06-29 -1.084833  0.559696  0.939469 -0.978481 -0.039012      0.957425
# 2022-06-30  0.503097  0.406414  0.323461 -0.493411 -0.169950      0.243454
# 2022-07-01 -0.792017 -0.842368 -1.279503  0.245715 -1.033787      0.060376
# 2022-07-02 -0.044195  1.567633  1.051109  0.406368  1.457477      0.165135
# 2022-07-03 -0.168646 -3.189703  1.120132  1.332778  2.452910      1.776298
# 2022-07-04 -0.243339 -0.130031 -0.109017  1.556186  1.447169      2.421716
# 2022-07-05  0.128778 -2.066949 -0.885493 -1.104579 -1.990073      1.220096
# 2022-07-06  0.932866  2.059838 -0.934938 -1.612990 -2.547928      2.601737
# 2022-07-07  0.527070 -1.551101  0.329613 -1.136527 -0.806913      1.291693
#
#             log_col_d  new_log_col_d  bin_col_a   new_date  day  month  year  \
# ...

# %%
# Perform group by operation on week day and get count of data of each day.
df.groupby(by = 'week_Day').count()
# Out:
#            a  b  c  d  new  square_col_d  log_col_d  new_log_col_d  bin_col_a  \
# week_Day
# Friday     1  1  1  1    1             1          1              1          1
# Monday     1  1  1  1    1             1          1              1          1
# Saturday   1  1  1  1    1             1          1              1          1
# Sunday     1  1  1  1    1             1          1              1          1
# Thursday   2  2  2  2    2             2          0              2          2
# Tuesday    2  2  2  2    2             2          0              2          2
# Wednesday  2  2  2  2    2             2          0              2          2
#
#            new_date  day  month  year
# week_Day
# Friday            1    1      1     1
# Monday            1    1      1     1
# Saturday          1    1      1     1
# Sunday            1    1      1     1
# Thursday          2    2      2     2
# Tuesday           2    2      2     2
# Wednesday         2    2      2     2
